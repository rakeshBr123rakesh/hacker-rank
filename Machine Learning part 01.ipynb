# %% [markdown]
# Machine learning with python : Linear regression with one variable
#
# sample problem for predicting home price inmonroe ,new jersey (USA)
#
# below table represents current home prices in mmonroe township based on square feet area ,new jersey
# ![image.png](attachment:00b7644d-1829-4746-9a7e-828d319bd33c.png)![image.png](attachment:77f5e471-48f9-4b1e-b517-ff3b5570f0ff.png)
# Problem statement : Given above data build a machine learning model that can predict home prices based on square feet area
#
#
# You can represent values in above table as a scatter plot (values are shown in red markers). After that one can draw a straight line that best fits values on chart.
#
# ![image.png](attachment:1435ad78-aba8-453e-a077-9de2b07837a2.png)![image.png](attachment:a965a8e7-ffb5-404a-8deb-81f8947c35b3.png)
#
#
# You can draw multiple lines like this but we choose the one where total sum of error is minimum
#
# ![image.png](attachment:6efd7b51-029a-47f0-8273-0ef1917f1881.png)![image.png](attachment:f3c4d037-a9d3-4a97-b11c-0525a2cd93ee.png)
#
# You might remember about linear equation from your high school days math class. Home prices can be presented as following equation,
#
# home price = m * (area) + b
#
# Generic form of same equation is
#
# ![image.png](attachment:b8161128-fc47-4007-9403-24147236dd86.png)![image.png](attachment:9708ab2f-31db-4d81-8289-62e30cbfb20b.png)

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("D:/career/sem 1/AI/AI_Data/homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel("area")
plt.ylabel("price")
plt.scatter(df.area,df.price,color="red",marker="+")

# %%
new_df=df.drop("price",axis="columns")
new_df
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
price=df.price
price
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %%
reg=linear_model.LinearRegression()
reg.fit(new_df,price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# C:\Users\rakes\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %% [markdown]
# Y=m*X+b(m is coefficient and b is intercept)

# %%
3300*135.78767123+180616.43835616432
# Out:
# 628715.7534151643

# %%
reg.predict([[5000]])
# Out:
# C:\Users\rakes\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %% [markdown]
# generate CSV file with list of home price predictions

# %%
area_df=pd.read_csv("D:/career/sem 1/AI/AI_Data/areas.csv")
area_df
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
p=reg.predict(area_df)
p
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
area_df["prices"]=p
area_df
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
area_df.to_csv("D:/career/sem 1/AI/AI_Data/prediction_linear_reg.csv")

# %% [raw]
# Machine Learning with python : Linear Regression Multiple Variabeles

# %% [markdown]
# sample problem of predicting home price in monroe,new jersey (USA)
# Below is the table containing home prices in monroe te=wp,NJ> here price deprends on atrea(square feet),bedrooms and age of the home (in year)> Given these prices we have to predict of new homes based on area bedrooms and age
#
# ![image.png](attachment:cdf69004-e397-4284-8f26-3a728b51e651.png)![image.png](attachment:b453bb74-63db-4e13-b64d-99f7a7c28371.png)
#
#
# Given these home price sfind out prices of a home that has
#
#
# 3000 sqft area , 3 bedrooms ,40 years old
# 2500 sqft area ,4 bedrooms ,5 years old
#
# We will use regression with multiple variable here >price can be calculating using following equation
#
#
# ![image.png](attachment:44b7b147-c76a-4232-b611-ffd78e2bf176.png)![image.png](attachment:f1fe79c1-f588-4a57-9712-846be3b3f33b.png)
#
#
# here area ,bedrooms ,age are called independent variable or features whereas price is dependent variable

# %% [markdown]
# import pandas as pd
# import numpy as np
# from sklearn import linear_model

# %%
df=pd.read_csv("D:/career/sem 1/AI/AI_Data/homeprice.csv")
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %% [markdown]
# Data Prepricessing : fill NA values with median avlues of a column

# %%
df.bedrooms.median()
# Out:
# 4.0

# %%
df.bedrooms=df.bedrooms.fillna(df.bedrooms.median())

# %%
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
reg=linear_model.LinearRegression()
reg.fit(df.drop("price",axis="columns"),df.price)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([  112.06244194, 23388.88007794, -3231.71790863])

# %%
reg.intercept_
# Out:
# 221323.0018654043

# %% [markdown]
# Find price of home with 3000 sqft area,3 bedrooms ,40 years old

# %%
reg.predict([[3000,3,40]])
# Out:
# C:\Users\rakes\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([498408.25158031])

# %%
112.06244194*3000 + 23388.88007794*3 + -3231.71790863*40 + 221323.00186540384
# Out:
# 498408.25157402386

# %% [markdown]
# find price of home with 2500sqft,4 bedrooms ,5 years old

# %%
reg.predict([[2500,4,40]])
# Out:
# C:\Users\rakes\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([465765.91068718])

# %% [markdown]
# Multivariate linear regression on hiring data

# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
from word2number import w2n

# %%
pip install word2number
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
d=pd.read_csv("D:/career/sem 1/AI/AI_Data/hiring.csv")
d
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
d.experience=d.experience.fillna("zero")
d
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    NaN                           7      72000
# 7          11                    7.0                           8      80000

# %%
d.experience = d.experience.apply(w2n.word_to_num)
d

# %%
import math

# %%
median_score=math.floor(d["test_score(out of 10)"].mean())
median_score
# Out:
# 7

# %%
d["test_score(out of 10)"]=d["test_score(out of 10)"].fillna(median_score)
d
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    7.0                           7      72000
# 7          11                    7.0                           8      80000

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(d[["experience","test_score(out of 10)","interview_score(out of 10)"]],d["salary($)"])
# Out:
# LinearRegression()

# %%
reg.predict([[2,9,6]])
# Out:
# C:\Users\rakes\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([53713.86677124])

# %%
reg.predict([[0,8,8]])
# Out:
# C:\Users\rakes\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([49942.98477434])

# %% [markdown]
# gradient descent

# %%
import numpy as np

def gradint_descent(x,y):
    m_curr=b_curr=0
    iterators=0
    n=len(x)
    learning_rate=0.8

    for i in range(iterators):
        y_predicted=m_curr*x+b_curr
        cost=(1/n)*sum([val**2 for val in (y-y_predicted)])
        md=-(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))

x=np.array([1,2,3,4,5])
y=np.array([5,7,9,11,13])
gradint_descent(x,y)

# %% [markdown]
# Machine Learning with Python : save and Load Trained Model

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
df=pd.read_csv("D:/career/sem 1/AI/AI_Data/homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
model=linear_model.LinearRegression()
model.fit(df[["area"]],df.price)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([135.78767123])

# %%
model.intercept_
# Out:
# 180616.43835616432

# %%
model.predict([[5000]])
# Out:
# C:\Users\rakes\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %% [markdown]
# Save Model To fit s file using python pickle

# %%
import pickle

# %%
with open("model_pickle","wb") as file:
    pickle.dump(model,file)

# %% [markdown]
# Load saved file

# %%
with open("model_pickle","rb") as file:
    mp=pickle.load(file)

# %%
mp.coef_
# Out:
# array([135.78767123])

# %%
mp.intercept_
# Out:
# 180616.43835616432

# %% [markdown]
# Save trained model using joblib

# %%
import joblib

# %%
pip install joblib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
joblib.dump(model,"model_joblib")
# Out:
# ['model_joblib']

# %%
mj=joblib.load("model_joblib")

# %%
mj.coef_
# Out:
# array([135.78767123])

# %%
mj.intercept_
# Out:
# 180616.43835616432

# %%
mj.predict([[5000]])
# Out:
# C:\Users\rakes\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %% [markdown]
# Categorical variables and one hot encoding

# %%
import pandas as pd

# %%
df=pd.read_csv("D:career/sem 1/AI/AI_Data/homeprices_one_hot.csv")
df
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9       robinsville  2600  575000
# 10      robinsville  2900  600000
# 11      robinsville  3100  620000
# 12      robinsville  3600  695000

# %%
dummies=pd.get_dummies(df.town).astype(int)
dummies
# Out:
#     monroe township  robinsville  west windsor
# 0                 1            0             0
# 1                 1            0             0
# 2                 1            0             0
# 3                 1            0             0
# 4                 1            0             0
# 5                 0            0             1
# 6                 0            0             1
# 7                 0            0             1
# 8                 0            0             1
# 9                 0            1             0
# 10                0            1             0
# 11                0            1             0
# 12                0            1             0

# %%
merged=pd.concat([df,dummies],axis="columns")
merged
# Out:
#                town  area   price  monroe township  robinsville  west windsor
# 0   monroe township  2600  550000                1            0             0
# 1   monroe township  3000  565000                1            0             0
# 2   monroe township  3200  610000                1            0             0
# 3   monroe township  3600  680000                1            0             0
# 4   monroe township  4000  725000                1            0             0
# 5      west windsor  2600  585000                0            0             1
# 6      west windsor  2800  615000                0            0             1
# 7      west windsor  3300  650000                0            0             1
# 8      west windsor  3600  710000                0            0             1
# 9       robinsville  2600  575000                0            1             0
# 10      robinsville  2900  600000                0            1             0
# ...

# %%
final=merged.drop(["town"],axis="columns")
final
# Out:
#     area   price  monroe township  robinsville  west windsor
# 0   2600  550000                1            0             0
# 1   3000  565000                1            0             0
# 2   3200  610000                1            0             0
# 3   3600  680000                1            0             0
# 4   4000  725000                1            0             0
# 5   2600  585000                0            0             1
# 6   2800  615000                0            0             1
# 7   3300  650000                0            0             1
# 8   3600  710000                0            0             1
# 9   2600  575000                0            1             0
# 10  2900  600000                0            1             0
# 11  3100  620000                0            1             0
# 12  3600  695000                0            1             0

# %% [markdown]
# Dummy Variables
#
# When you can derive variables from other variables they are known to be multi-cilinear. Here if you know values of colonia and gorgia  then you can easily infer value of new jersey state i.e. california=0 and georgia=0 .There for these state variables are called to be multi colonial >In this situation linear tregression dont work properly so we need to drop on ecolumn

# %% [markdown]
# NOTE:sklearn library takes care of dummy variables trap hence even if you dont drop one of the state columns it is going to work, hower we should make a habit of taking care of dummy variable trap ourself just in case library that you are using is not handling this for you

# %%
final=final.drop(["west windsor"],axis="columns")
final
# Out:
#     area   price  monroe township  robinsville
# 0   2600  550000                1            0
# 1   3000  565000                1            0
# 2   3200  610000                1            0
# 3   3600  680000                1            0
# 4   4000  725000                1            0
# 5   2600  585000                0            0
# 6   2800  615000                0            0
# 7   3300  650000                0            0
# 8   3600  710000                0            0
# 9   2600  575000                0            1
# 10  2900  600000                0            1
# 11  3100  620000                0            1
# 12  3600  695000                0            1

# %%
X=final.drop(["price"],axis="columns")
X
# Out:
#     area  monroe township  robinsville
# 0   2600                1            0
# 1   3000                1            0
# 2   3200                1            0
# 3   3600                1            0
# 4   4000                1            0
# 5   2600                0            0
# 6   2800                0            0
# 7   3300                0            0
# 8   3600                0            0
# 9   2600                0            1
# 10  2900                0            1
# 11  3100                0            1
# 12  3600                0            1

# %%
y=final.price

# %%
from sklearn.linear_model import LinearRegression 
model=LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.predict(X)
# Out:
# array([539709.7398409 , 590468.71640508, 615848.20468716, 666607.18125134,
#        717366.15781551, 579723.71533005, 605103.20361213, 668551.92431735,
#        706621.15674048, 565396.15136531, 603465.38378844, 628844.87207052,
#        692293.59277574])

# %%
model.score(X,y)
# Out:
# 0.9573929037221872

# %%
model.predict([[3400,0,0]])
# Out:
# C:\Users\rakes\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([681241.66845839])

# %%
model.predict([[2800,0,1]])
# Out:
# C:\Users\rakes\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([590775.63964739])

# %% [markdown]
# using sklearn OneHotEncoder
#
# First step to use label encoder to convert town names into numbers

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
dfle=df
dfle.town=le.fit_transform(dfle.town)
dfle
# Out:
#     town  area   price
# 0      0  2600  550000
# 1      0  3000  565000
# 2      0  3200  610000
# 3      0  3600  680000
# 4      0  4000  725000
# 5      2  2600  585000
# 6      2  2800  615000
# 7      2  3300  650000
# 8      2  3600  710000
# 9      1  2600  575000
# 10     1  2900  600000
# 11     1  3100  620000
# 12     1  3600  695000

# %%
X=dfle[["town","area"]].values

# %%
X
# Out:
# array([[   0, 2600],
#        [   0, 3000],
#        [   0, 3200],
#        [   0, 3600],
#        [   0, 4000],
#        [   2, 2600],
#        [   2, 2800],
#        [   2, 3300],
#        [   2, 3600],
#        [   1, 2600],
#        [   1, 2900],
#        [   1, 3100],
#        [   1, 3600]], dtype=int64)

# %%
y=dfle.price.values

# %%
y
# Out:
# array([550000, 565000, 610000, 680000, 725000, 585000, 615000, 650000,
#        710000, 575000, 600000, 620000, 695000], dtype=int64)

# %% [markdown]
# Training and Testing Available data

# %% [markdown]
# we have a dataset containing prices of uswd BMW cars. WE rae going to nalyze this dataset and build a prediction function that can predict a price by taking mileage and age of the car as input .WE will use sklearn irain_test_split method to split training and testing data

# %%
import pandas as pd
df=pd.read_csv("D:/career/sem 1/AI/AI_Data/carprices.csv")
df

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Car Mileage VS sell price($)

# %%
plt.scatter(df["Mileage"],df["Sell Price($)"])

# %% [markdown]
# Car Milege VS sell price($)

# %%
plt.scatter(df["Mileage"],df["Sell Price($)"])

# %% [markdown]
# Car Age Vs Sell Price ($)

# %%
plt.scatter(df["Age(yrs)"],df["Sell Price($)"])

# %% [markdown]
# Looking at above two scatter plots, using linear regression model makes sense as we can clearly see a linear relationship between our dependant (i.e. Sell Price) and independant variables (i.e. car age and car mileage)
#
# The approach we are going to use here is to split available data in two sets
#
# Training: We will train our model on this dataset
# Testing: We will use this subset to make actual predictions using trained model
#
#
#
#
# The reason we don't use same training set for testing is because our model has seen those samples before, using same samples for making predictions might give us wrong impression about accuracy of our model. It is like you ask same questions in exam paper as you tought the students in the class.

# %%
x=df[["Mileage","Age(yrs)"]]

# %%
y=df[["Sell Price($)"]]

# %%
from sklearn.model_selection import train_test_split
#X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)
